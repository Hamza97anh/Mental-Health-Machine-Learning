# %%
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
import numpy as np

# %%
file = pd.read_csv('../../Deliverable2/HM/Data_Clean_2017_to_2019.csv')
df = pd.DataFrame(file)
df.head()
# Out:
#    Index   age  Gender: F=0, M=1, Non-binary=3  \
# 0      0  25.0                               1
# 1      1  51.0                               1
# 2      2  27.0                               1
# 3      3  37.0                               1
# 4      4  46.0                               1
#
#   If possibly, what disorder(s) do you believe you have?  \
# 0                                                NaN
# 1  Mood Disorder (Depression, Bipolar Disorder, etc)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Have you ever been diagnosed with a mental health disorder? Y=1 N=0  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %%
df['age'].unique()
# Out:
# array([25., 51., 27., 37., 46., 36., 39., 35., 49., 45., 40., 31., 26.,
#        43., 32., 41., 53., 29., 28., 24., 42., 34., 23., 30., 58., 50.,
#        52., 33., 54., 38., 64., 55., 60., 47., 48., 20.,  0., 22., 63.,
#        44., 59., 19., 56., 21., 57., 61., 67., 65., 18., 66., 62., nan])

# %%
df['age'].isna().count()
# Out:
# 1525

# %%
df = df.fillna(0)
df.head()
# Out:
#    Index   age  Gender: F=0, M=1, Non-binary=3  \
# 0      0  25.0                               1
# 1      1  51.0                               1
# 2      2  27.0                               1
# 3      3  37.0                               1
# 4      4  46.0                               1
#
#   If possibly, what disorder(s) do you believe you have?  \
# 0                                                  0
# 1  Mood Disorder (Depression, Bipolar Disorder, etc)
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Have you ever been diagnosed with a mental health disorder? Y=1 N=0  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %%
df['age'].unique()
# Out:
# array([25., 51., 27., 37., 46., 36., 39., 35., 49., 45., 40., 31., 26.,
#        43., 32., 41., 53., 29., 28., 24., 42., 34., 23., 30., 58., 50.,
#        52., 33., 54., 38., 64., 55., 60., 47., 48., 20.,  0., 22., 63.,
#        44., 59., 19., 56., 21., 57., 61., 67., 65., 18., 66., 62.])
