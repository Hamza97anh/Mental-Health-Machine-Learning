# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
import numpy as np

# %%
#Load 2017 data
csv_2017 = pd.read_csv('OSMI Mental Health in Tech Survey 2017.csv')

data_2017 = pd.DataFrame(csv_2017)
data_2017.head(5)
# Out:
#                                   #  Are you self-employed?  \
# 0  e49fe87572831232dcfa51b376b22039                       0
# 1  a1eede444ac024928d247a8372d54931                       0
# 2  37d3fd67f62bd1e0a2dea4f9cd440d98                       0
# 3  519b759442c1cab0e9b5a8a1acb1b216                       0
# 4  ef0af4927b575b1a3e607c11ca37870e                       1
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                             25-Jun
# 3                                     More than 1000
# 4                                                NaN
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# ...

# %%
data_2017.count()
# Out:
# #                                                               756
# Are you self-employed?                                          756
# How many employees does your company or organization have?      643
# Is your employer primarily a tech company/organization?         643
# Is your primary role within your company related to tech/IT?    643
#                                                                ...
# What country do you work in?                                    754
# What US state or territory do you work in?                      503
# Start Date (UTC)                                                756
# Submit Date (UTC)                                               756
# Network ID                                                      756
# Length: 123, dtype: int64

# %%
csv_2018 = pd.read_csv('OSMI Mental Health in Tech Survey 2018.csv')
data_2018 = pd.DataFrame(csv_2018)
data_2018.head(5)
# Out:
#                                   #  Are you self-employed?  \
# 0  e44a0a34f2465940beda2a1537e9b99e                       0
# 1  0d698e3beca20fb75f19b9d528e36d73                       0
# 2  61a40c9071eb36fa9caa254d31500c41                       0
# 3  f8624340bead7deb08abb766704ddf6b                       0
# 4  31d3ae93b68d79e504a0a643601b6b1e                       0
#
#   How many employees does your company or organization have?  \
# 0                                     More than 1000
# 1                                     More than 1000
# 2                                             25-Jun
# 3                                             25-Jun
# 4                                             26-100
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# ...

# %%
data_2018.count()
# Out:
# #                                                               417
# Are you self-employed?                                          417
# How many employees does your company or organization have?      361
# Is your employer primarily a tech company/organization?         361
# Is your primary role within your company related to tech/IT?    361
#                                                                ...
# What country do you work in?                                    417
# What US state or territory do you work in?                      314
# Start Date (UTC)                                                417
# Submit Date (UTC)                                               417
# Network ID                                                      417
# Length: 123, dtype: int64

# %%
csv_2019 = pd.read_csv('OSMI 2019 Mental Health in Tech Survey Results - OSMI Mental Health in Tech Survey 2019.csv')
data_2019 = pd.DataFrame(csv_2019)
data_2019.head(5)
# Out:
#    Are you self-employed?  \
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
# ...

# %%
#Merge datset2017 and 2018 on "Are you self employed"
merged = data_2017.merge(data_2018, on='Are you self-employed?')
merged.head(5)

#merged.to_csv('result.csv', index=False)
# Out:
#                                 #_x  Are you self-employed?  \
# 0  e49fe87572831232dcfa51b376b22039                       0
# 1  e49fe87572831232dcfa51b376b22039                       0
# 2  e49fe87572831232dcfa51b376b22039                       0
# 3  e49fe87572831232dcfa51b376b22039                       0
# 4  e49fe87572831232dcfa51b376b22039                       0
#
#   How many employees does your company or organization have?_x  \
# 0                                            100-500
# 1                                            100-500
# 2                                            100-500
# 3                                            100-500
# 4                                            100-500
#
#    Is your employer primarily a tech company/organization?_x  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# ...

# %%
#merge dataset2017,2018,2019 on "Are you self-employed"
merged_1 = merged.merge(data_2019,on= "Are you self-employed?")
merged_1.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6441f430d498> in <module>
#       1 #merge dataset2017,2018,2019 on "Are you self-employed"
# ----> 2 merged_1 = merged.merge(data_2019,on= "Are you self-employed?")
#       3 merged_1.head(5)
#
# NameError: name 'merged' is not defined
